# %% [markdown]
# # Zilow Zestimate

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from random import shuffle
from gc import collect

from bokeh.charts import show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.io import output_notebook
output_notebook()

import warnings

warnings.filterwarnings("ignore")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bc1ea036-46d7-4be9-b1a9-31ed8328bf46">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # The Data

# %%
def normalize(column):
    norm_column = (column - column.min()) / (column.max() - column.min())
    return norm_column
    
def normalize_columns(data, columns):
    df = data.copy()
    for column in columns:
        df[column] = normalize(df[column])
    return df

# %%
# data = pd.read_csv("../data/train_complete_2016.csv")
# data.shape

train = pd.read_csv("../data/train.csv", index_col=0)
test = pd.read_csv("../data/test.csv", index_col=0)

# test_target = test["logerror"]
# train_target = train["logerror"]

# del test["logerror"]
# del train["logerror"]

# %%
train.head()
# Out:
#        parcelid  logerror transactiondate  airconditioningtypeid  \
# 66450  12149460    0.0363      2016-08-12                    1.0
# 16762  11962551    0.0218      2016-03-16                    1.0
# 63556  10734901    0.0100      2016-08-04                    1.0
# 36025  11104067    0.0060      2016-05-17                    NaN
# 30783  12678699   -0.0111      2016-04-29                    NaN
#
#        architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 66450                       NaN           NaN          3.0         4.0
# 16762                       NaN           NaN          4.0         3.0
# 63556                       NaN           NaN          3.0         3.0
# 36025                       NaN           NaN          3.0         4.0
# 30783                       NaN           NaN          2.0         3.0
#
#        buildingclasstypeid  buildingqualitytypeid         ...           \
# 66450                  NaN                    4.0         ...
# 16762                  NaN                    4.0         ...
# 63556                  NaN                    4.0         ...
# 36025                  NaN                    7.0         ...
# 30783                  NaN                    7.0         ...
#
#        numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 66450              NaN            NaN                    180637.0
# 16762              NaN            NaN                    182151.0
# 63556              NaN            NaN                    141380.0
# 36025              NaN            NaN                    163569.0
# 30783              NaN            NaN                     27108.0
#
#        taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 66450           722923.0          2015.0               542286.0    8080.91
# 16762           291440.0          2015.0               109289.0    3690.38
# 63556           193171.0          2015.0                51791.0    6234.70
# 36025           272612.0          2015.0               109043.0    4848.37
# 30783            91344.0          2015.0                64236.0    1305.15
#
#        taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 66450                 NaN                 NaN         6.037300e+13
# 16762                 NaN                 NaN         6.037186e+13
# 63556                 NaN                 NaN         6.037137e+13
# 36025                 NaN                 NaN         6.037920e+13
# 30783                 NaN                 NaN         6.037651e+13
#
# [5 rows x 60 columns]

# %%
test.head()
# Out:
#     parcelid  logerror transactiondate  airconditioningtypeid  \
# 1   14366692   -0.1684      2016-01-01                    NaN
# 3   12643413    0.0218      2016-01-02                    1.0
# 4   14432541   -0.0050      2016-01-02                    NaN
# 5   11509835   -0.2705      2016-01-02                    1.0
# 11  11672170   -0.0161      2016-01-03                    1.0
#
#     architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 1                        NaN           NaN          3.5         4.0
# 3                        NaN           NaN          2.0         2.0
# 4                        NaN           NaN          2.5         4.0
# 5                        NaN           NaN          4.0         4.0
# 11                       NaN           NaN          4.0         5.0
#
#     buildingclasstypeid  buildingqualitytypeid         ...           \
# 1                   NaN                    NaN         ...
# 3                   NaN                    4.0         ...
# 4                   NaN                    NaN         ...
# 5                   NaN                    1.0         ...
# 11                  NaN                    1.0         ...
#
#     numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 1               NaN            NaN                    346458.0
# 3               NaN            NaN                    171518.0
# 4               2.0            NaN                    169574.0
# 5               NaN            NaN                    880650.0
# 11              NaN            NaN                    559040.0
#
#     taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 1            585529.0          2015.0               239071.0   10153.02
# 3            244880.0          2015.0                73362.0    3048.74
# 4            434551.0          2015.0               264977.0    5488.96
# 5           2447951.0          2015.0              1567301.0   27126.57
# 11          1090127.0          2015.0               531087.0   13428.94
#
#     taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 1                  NaN                 NaN                  NaN
# 3                  NaN                 NaN         6.037296e+13
# 4                  NaN                 NaN         6.059042e+13
# 5                  NaN                 NaN         6.037621e+13
# 11                 NaN                 NaN         6.037263e+13
#
# [5 rows x 60 columns]

# %%
numeric_columns = ['basementsqft', 'bathroomcnt', 'bedroomcnt', 
                   'threequarterbathnbr', 'finishedfloor1squarefeet', 
                   'calculatedfinishedsquarefeet', 
                   'finishedsquarefeet6', 'finishedsquarefeet12', 'finishedsquarefeet13', 
                   'finishedsquarefeet15', 'finishedsquarefeet50', 'fireplacecnt', 
                   'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'latitude', 
                   'longitude', 'lotsizesquarefeet', 'poolsizesum', 'roomcnt', 'unitcnt', 
                   'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt', 'taxamount',
                   'structuretaxvaluedollarcnt', 'landtaxvaluedollarcnt']

# %% [markdown]
# ### Attribute correlation
# Plotting attribute correlation with the target column.

# %%
def plot_correlation(data, column_name, alpha=0.2, sample_ratio=1):
    p = figure(plot_width=300, plot_height=300, title=column_name + " vs " + "logerror", tools=["xwheel_zoom", "xpan"])
    n_sample = int(sample_ratio * len(data))
    data_plot = data.sample(n_sample)
    p.circle(data_plot[column_name], data_plot["logerror"], alpha=alpha)
    return p

def correlations_df(data, column_name):
    corr = data[column_name].corr(data["logerror"])
    sign = '+' if corr >= 0 else '-'
    corr = corr if corr >= 0 else corr * -1
    
    return corr_df.append(pd.DataFrame([{"attribute": column_name, "sign": sign, "corr": corr}]))

# %%
corr_df = pd.DataFrame()
grid = [[]]

for column_name in numeric_columns: 
    corr_df = correlations_df(train, column_name)
    
    p = plot_correlation(train, column_name, alpha=0.1, sample_ratio=0.25)
    
    if len(grid[-1]) % 3 == 0:
        grid.append([p])
    else:
        grid[-1].append(p)
        
# show(gridplot(grid))

# %%
corr_df.sort_values("corr", ascending=False)
# Out:
#                       attribute      corr sign
# 0                  basementsqft  0.226881    +
# 0          finishedsquarefeet13  0.054005    -
# 0            yardbuildingsqft26  0.050029    +
# 0           finishedsquarefeet6  0.046738    +
# 0                   poolsizesum  0.041860    +
# 0          finishedsquarefeet12  0.040015    +
# 0  calculatedfinishedsquarefeet  0.036703    +
# 0      finishedfloor1squarefeet  0.030734    +
# 0          finishedsquarefeet50  0.029448    +
# 0                   fullbathcnt  0.026546    +
# 0                   bathroomcnt  0.024773    +
# 0                  fireplacecnt  0.024117    +
# 0                  garagecarcnt  0.022919    +
# 0    structuretaxvaluedollarcnt  0.022686    +
# 0                    bedroomcnt  0.021636    +
# 0               garagetotalsqft  0.020482    +
# 0           threequarterbathnbr  0.018637    +
# 0            yardbuildingsqft17  0.016419    -
# 0                     yearbuilt  0.013327    +
# 0                       unitcnt  0.007665    -
# 0             lotsizesquarefeet  0.005314    +
# 0                      latitude  0.004542    +
# 0                     taxamount  0.004481    -
# 0          finishedsquarefeet15  0.004271    +
# 0                     longitude  0.001437    -
# 0                       roomcnt  0.001195    +
# 0         landtaxvaluedollarcnt  0.000582    -

# %% [markdown]
# ### Missing values
# Replacing missing values with column <b>mode</b>

# %%
def column_mode(column):
    return column.value_counts().sort_values(ascending=False).index.tolist()[0]

# %%
data = train.append(test)

# %%
sample5 = train.sample(5)
sample5[numeric_columns]
# Out:
#        basementsqft  bathroomcnt  bedroomcnt  threequarterbathnbr  \
# 17547           NaN          2.0         3.0                  NaN
# 80034           NaN          2.0         2.0                  NaN
# 47040           NaN          2.5         5.0                  1.0
# 82414           NaN          1.0         1.0                  NaN
# 66603           NaN          4.5         4.0                  1.0
#
#        finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 17547                       NaN                        1131.0
# 80034                       NaN                        1089.0
# 47040                    1130.0                        2417.0
# 82414                       NaN                         678.0
# 66603                    4425.0                        4425.0
#
#        finishedsquarefeet6  finishedsquarefeet12  finishedsquarefeet13  \
# 17547                  NaN                1131.0                   NaN
# 80034                  NaN                1089.0                   NaN
# 47040                  NaN                2417.0                   NaN
# 82414                  NaN                 678.0                   NaN
# 66603                  NaN                4425.0                   NaN
#
#        finishedsquarefeet15          ...            lotsizesquarefeet  \
# 17547                   NaN          ...                       4961.0
# 80034                   NaN          ...                     116052.0
# 47040                   NaN          ...                       6226.0
# 82414                   NaN          ...                          NaN
# 66603                   NaN          ...                      23528.0
#
#        poolsizesum  roomcnt  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 17547          NaN      0.0      1.0                 NaN                 NaN
# 80034          NaN      0.0      1.0                 NaN                 NaN
# 47040          NaN      9.0      NaN                 NaN                 NaN
# 82414          NaN      0.0      NaN                 NaN                 NaN
# 66603          NaN      9.0      NaN                 NaN                 NaN
#
#        yearbuilt  taxamount  structuretaxvaluedollarcnt  landtaxvaluedollarcnt
# 17547     1950.0    4992.75                    140043.0               242449.0
# 80034     1990.0    3138.58                    126932.0               111065.0
# 47040     1999.0    7122.82                    219000.0               407000.0
# 82414     1990.0    2987.84                     85824.0               156905.0
# 66603     2014.0   16543.60                    535106.0               994000.0
#
# [5 rows x 27 columns]

# %%
for column_name in data.columns.tolist():
    mode = column_mode(data[column_name])
    data[column_name] = data[column_name].fillna(mode)

# %%
sample5 = data.loc[sample5.index.tolist()]
sample5[numeric_columns]
# Out:
#        basementsqft  bathroomcnt  bedroomcnt  threequarterbathnbr  \
# 17547        1528.0          2.0         3.0                  1.0
# 80034        1528.0          2.0         2.0                  1.0
# 47040        1528.0          2.5         5.0                  1.0
# 82414        1528.0          1.0         1.0                  1.0
# 66603        1528.0          4.5         4.0                  1.0
#
#        finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 17547                    1260.0                        1131.0
# 80034                    1260.0                        1089.0
# 47040                    1130.0                        2417.0
# 82414                    1260.0                         678.0
# 66603                    4425.0                        4425.0
#
#        finishedsquarefeet6  finishedsquarefeet12  finishedsquarefeet13  \
# 17547                720.0                1131.0                1440.0
# 80034                720.0                1089.0                1440.0
# 47040                720.0                2417.0                1440.0
# 82414                720.0                 678.0                1440.0
# 66603                720.0                4425.0                1440.0
#
#        finishedsquarefeet15          ...            lotsizesquarefeet  \
# 17547                1680.0          ...                       4961.0
# 80034                1680.0          ...                     116052.0
# 47040                1680.0          ...                       6226.0
# 82414                1680.0          ...                       6000.0
# 66603                1680.0          ...                      23528.0
#
#        poolsizesum  roomcnt  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 17547        450.0      0.0      1.0               240.0               120.0
# 80034        450.0      0.0      1.0               240.0               120.0
# 47040        450.0      9.0      1.0               240.0               120.0
# 82414        450.0      0.0      1.0               240.0               120.0
# 66603        450.0      9.0      1.0               240.0               120.0
#
#        yearbuilt  taxamount  structuretaxvaluedollarcnt  landtaxvaluedollarcnt
# 17547     1950.0    4992.75                    140043.0               242449.0
# 80034     1990.0    3138.58                    126932.0               111065.0
# 47040     1999.0    7122.82                    219000.0               407000.0
# 82414     1990.0    2987.84                     85824.0               156905.0
# 66603     2014.0   16543.60                    535106.0               994000.0
#
# [5 rows x 27 columns]

# %%
for column in data.columns.tolist():
    #columns must not contains nan
    assert (False == (True in data[column].isnull().tolist()))

# %% [markdown]
# ##### Normalizing the data

# %%
norm_data = normalize_columns(data, numeric_columns)

sample5 = norm_data.loc[sample5.index.tolist()]
sample5[numeric_columns]
# Out:
#        basementsqft  bathroomcnt  bedroomcnt  threequarterbathnbr  \
# 17547      0.981443        0.100      0.1875                  0.0
# 80034      0.981443        0.100      0.1250                  0.0
# 47040      0.981443        0.125      0.3125                  0.0
# 82414      0.981443        0.050      0.0625                  0.0
# 66603      0.981443        0.225      0.2500                  0.0
#
#        finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 17547                  0.160401                      0.049650
# 80034                  0.160401                      0.047803
# 47040                  0.143253                      0.106205
# 82414                  0.160401                      0.029729
# 66603                  0.577892                      0.194512
#
#        finishedsquarefeet6  finishedsquarefeet12  finishedsquarefeet13  \
# 17547             0.066456              0.056419              0.727273
# 80034             0.066456              0.054320              0.727273
# 47040             0.066456              0.120684              0.727273
# 82414             0.066456              0.033781              0.727273
# 66603             0.066456              0.221028              0.727273
#
#        finishedsquarefeet15          ...            lotsizesquarefeet  \
# 17547              0.050494          ...                     0.000688
# 80034              0.050494          ...                     0.016624
# 47040              0.050494          ...                     0.000869
# 82414              0.050494          ...                     0.000837
# 66603              0.050494          ...                     0.003351
#
#        poolsizesum  roomcnt  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 17547     0.245064      0.0      0.0             0.08104            0.075668
# 80034     0.245064      0.0      0.0             0.08104            0.075668
# 47040     0.245064      0.5      0.0             0.08104            0.075668
# 82414     0.245064      0.0      0.0             0.08104            0.075668
# 66603     0.245064      0.5      0.0             0.08104            0.075668
#
#        yearbuilt  taxamount  structuretaxvaluedollarcnt  landtaxvaluedollarcnt
# 17547   0.500000   0.015358                    0.014067               0.009895
# 80034   0.807692   0.009598                    0.012749               0.004532
# 47040   0.876923   0.021976                    0.022004               0.016611
# 82414   0.807692   0.009130                    0.008617               0.006403
# 66603   0.992308   0.051243                    0.053780               0.040571
#
# [5 rows x 27 columns]

# %%
data = norm_data
train = data.iloc[train.index.tolist()]
test = data.iloc[test.index.tolist()]

data = None
norm_data = None
collect()
# Out:
# 9091

# %% [markdown]
# # Modeling v1 - Raw Attributes

# %%
from sklearn.linear_model import SGDRegressor, Ridge
from sklearn.neural_network import MLPRegressor

from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectKBest
from numpy import median

# %%
def scorer(estimator, X, y):
    pred = estimator.predict(X)
    return mean_absolute_error(pred, y)

# def partition(data, train_proportion=0.7):
#     train = data.sample( int(len(data) * train_proportion) )

#     test_indexes = set(data.index.tolist()) - set(train.index.tolist())
#     test = data.loc[test_indexes]
    
#     return train, test

def scores(model, train, target, k, scorer=scorer):
    train_score = scorer(model.fit(train, target), train, target)

    cv_scores = cross_val_score(model, train, target, cv=k, scoring=scorer)
    
    return {"train": train_score, "validation": median(cv_scores)}

# %% [markdown]
# ##### Use columns

# %%
skb = SelectKBest(k=10)
fit = skb.fit(train[numeric_columns], train["logerror"])

use_columns = train[numeric_columns].columns[fit.get_support()].tolist()
use_columns
# Out:
# ['bathroomcnt',
#  'threequarterbathnbr',
#  'calculatedfinishedsquarefeet',
#  'finishedsquarefeet12',
#  'finishedsquarefeet15',
#  'fullbathcnt',
#  'yearbuilt',
#  'taxamount',
#  'structuretaxvaluedollarcnt',
#  'landtaxvaluedollarcnt']

# %%
results = []
k = 5

# %% [markdown]
# ##### Train and test partitioning

# %%
# train, test = partition(data[use_columns + ["logerror"]], train_proportion=0.7)

# %% [markdown]
# ### <font color="blue">Linear Regression</font>

# %% [markdown]
# ##### Stochastic Gradient Descent Regressor

# %%
#model = SGDRegressor(alpha=0.001, max_iter=1000)
# cv_scores = cross_val_score(model, train[use_columns], train["logerror"], cv=k, scoring=scorer)
# print("median:", median(cv_scores))
# cv_scores

model = SGDRegressor(alpha=0.001, max_iter=1000)
scores_dict = scores(model, train[use_columns], train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069143339639002876, 'validation': 0.069195049576681697}

# %%
results.append({"model": "linear SGDRegressor", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "alpha0.001, max_iter=1000"})

# %% [markdown]
# ##### Ridge

# %%
# model = Ridge()
# cv_scores = cross_val_score(model, train[use_columns], train["logerror"], cv=k, scoring=scorer)
# print("median:", median(cv_scores))
# cv_scores

model = Ridge()
scores_dict = scores(model, train[use_columns], train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069254386114012356, 'validation': 0.069241820182844749}

# %%
results.append({"model": "linear Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"]})

# %%
# model = Ridge(alpha=2.0)
# cv_scores = cross_val_score(model, train[use_columns], train["logerror"], cv=k, scoring=scorer)
# print("median:", median(cv_scores))
# cv_scores

model = Ridge(alpha=2.0)
scores_dict = scores(model, train[use_columns], train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069249229942448476, 'validation': 0.069222834904631922}

# %%
results.append({"model": "linear Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "alpha=2"})

# %%
# model = Ridge(alpha=10.0)
# cv_scores = cross_val_score(model, train[use_columns], train["logerror"], cv=k, scoring=scorer)
# print("median:", median(cv_scores))
# cv_scores

model = Ridge(alpha=10.0)
scores_dict = scores(model, train[use_columns], train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069227841108432733, 'validation': 0.069201428365949003}

# %%
results.append({"model": "linear Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "alpha=10"})

# %%
model = Ridge(alpha=0.5)
scores_dict = scores(model, train[use_columns], train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069261427274144513, 'validation': 0.06926358705731521}

# %%
results.append({"model": "linear Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "alpha=0.5"})

# %%
model = Ridge(alpha=0.2)
scores_dict = scores(model, train[use_columns], train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069273219167527003, 'validation': 0.069276719752139795}

# %%
results.append({"model": "linear Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "alpha=0.2"})

# %% [markdown]
# ### <font color="blue">Polynomial Regression</font>

# %%
from sklearn.preprocessing import PolynomialFeatures

def polynomial_features(df, degrees=2):
    poly = PolynomialFeatures(degree=2)
    polinomial_data = pd.DataFrame(poly.fit_transform(df))
    polinomial_data.columns = poly.get_feature_names()
    return polinomial_data

# %%
poly_test = polynomial_features(test[use_columns], degrees=5)
poly_test.head()

poly_train = polynomial_features(train[use_columns], degrees=5)
poly_train.head()
# Out:
#      1    x0   x1        x2        x3        x4        x5        x6        x7  \
# 0  1.0  0.15  0.0  0.126171  0.143371  0.050494  0.105263  0.938462  0.046075
# 1  1.0  0.15  0.0  0.105633  0.120034  0.050494  0.105263  0.500000  0.043089
# 2  1.0  0.10  0.0  0.065394  0.074309  0.050494  0.052632  0.776923  0.010412
# 3  1.0  0.10  0.0  0.053696  0.061016  0.050494  0.052632  0.530769  0.002622
# 4  1.0  0.10  0.0  0.069572  0.079057  0.050494  0.052632  0.300000  0.022623
#
#          x8      ...           x6^2     x6 x7     x6 x8     x6 x9      x7^2  \
# 0  0.038490      ...       0.880710  0.043240  0.036122  0.011912  0.002123
# 1  0.023772      ...       0.250000  0.021545  0.011886  0.018269  0.001857
# 2  0.014623      ...       0.603609  0.008090  0.011361  0.001268  0.000108
# 3  0.002669      ...       0.281716  0.001392  0.001417  0.000499  0.000007
# 4  0.020450      ...       0.090000  0.006787  0.006135  0.004729  0.000512
#
#       x7 x8     x7 x9      x8^2     x8 x9          x9^2
# 0  0.001773  0.000585  0.001481  0.000489  1.611120e-04
# 1  0.001024  0.001574  0.000565  0.000869  1.334992e-03
# 2  0.000152  0.000017  0.000214  0.000024  2.662896e-06
# 3  0.000007  0.000002  0.000007  0.000003  8.842156e-07
# 4  0.000463  0.000357  0.000418  0.000322  2.484861e-04
#
# [5 rows x 66 columns]

# %% [markdown]
# ##### SGD Regressor

# %%
# model = SGDRegressor(max_iter=2000)
# cv_scores = cross_val_score(model, poly_train, train["logerror"], cv=k, scoring=scorer)
# print("median:", median(cv_scores))
# cv_scores

model = SGDRegressor(max_iter=2000)
scores_dict = scores(model, poly_train, train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069393688996941261, 'validation': 0.069134476015951962}

# %%
results.append({"model": "Polynomial SGD Regressor", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "degree=5"})

# %% [markdown]
# ##### Ridge

# %%
# model = Ridge()
# cv_scores = cross_val_score(model, poly_train, train["logerror"], cv=k, scoring=scorer)
# print("median:", median(cv_scores))
# cv_scores

model = Ridge()
scores_dict = scores(model, poly_train, train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069267568773309848, 'validation': 0.069280391365674418}

# %%
results.append({"model": "Polynomial Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "degree=5"})

# %%
model = Ridge(alpha=0.5)
scores_dict = scores(model, poly_train, train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.069267102171698708, 'validation': 0.069301282283425164}

# %%
results.append({"model": "Polynomial Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "degree=5, alpha=0.5"})

# %%
model = Ridge(alpha=10)
scores_dict = scores(model, poly_train, train["logerror"], k, scorer=scorer)
scores_dict
# Out:
# {'train': 0.06924949854472974, 'validation': 0.06922250059498268}

# %%
results.append({"model": "Polynomial Ridge", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "degree=5, alpha=10.0"})

# %%
results_df = pd.DataFrame(results)
results_df.sort_values("score_cv")
# Out:
#                       model  score_cv  score_train                       tags
# 6  Polynomial SGD Regressor  0.069134     0.069394                   degree=5
# 0       linear SGDRegressor  0.069195     0.069143  alpha0.001, max_iter=1000
# 3              linear Ridge  0.069201     0.069228                   alpha=10
# 9          Polynomial Ridge  0.069223     0.069249       degree=5, alpha=10.0
# 2              linear Ridge  0.069223     0.069249                    alpha=2
# 1              linear Ridge  0.069242     0.069254                        NaN
# 4              linear Ridge  0.069264     0.069261                  alpha=0.5
# 5              linear Ridge  0.069277     0.069273                  alpha=0.2
# 7          Polynomial Ridge  0.069280     0.069268                   degree=5
# 8          Polynomial Ridge  0.069301     0.069267        degree=5, alpha=0.5

# %%
# results_df.to_csv("results_df.csv", index=False)

# %%
mlp_results = []

# %% [markdown]
# ##### Multi Layer Perceptron Regressor

# %%
for hidden_layer_sizes in [10,50,100,150,300,450,600,1000,3000,5000,7000,9000]:
    model = MLPRegressor(hidden_layer_sizes=hidden_layer_sizes)
    print("hidden_layer_sizes:", hidden_layer_sizes)
    scores_dict = scores(model, train[use_columns], train["logerror"], k, scorer=scorer)
    mlp_results.append({"model": "linear MLP", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "hidden_layer_sizes=" + str(hidden_layer_sizes)})
    print(pd.DataFrame(mlp_results))
# Out:
# hidden_layer_sizes: 10
#         model  score_cv  score_train                   tags
# 0  linear MLP  0.069149     0.069428  hidden_layer_sizes=10
# hidden_layer_sizes: 50
#         model  score_cv  score_train                   tags
# 0  linear MLP  0.069149     0.069428  hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342  hidden_layer_sizes=50
# hidden_layer_sizes: 100
#         model  score_cv  score_train                    tags
# 0  linear MLP  0.069149     0.069428   hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342   hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053  hidden_layer_sizes=100
# hidden_layer_sizes: 150
#         model  score_cv  score_train                    tags
# 0  linear MLP  0.069149     0.069428   hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342   hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053  hidden_layer_sizes=100
# 3  linear MLP  0.070091     0.070335  hidden_layer_sizes=150
# hidden_layer_sizes: 300
#         model  score_cv  score_train                    tags
# 0  linear MLP  0.069149     0.069428   hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342   hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053  hidden_layer_sizes=100
# 3  linear MLP  0.070091     0.070335  hidden_layer_sizes=150
# 4  linear MLP  0.069267     0.069040  hidden_layer_sizes=300
# hidden_layer_sizes: 450
#         model  score_cv  score_train                    tags
# 0  linear MLP  0.069149     0.069428   hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342   hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053  hidden_layer_sizes=100
# 3  linear MLP  0.070091     0.070335  hidden_layer_sizes=150
# 4  linear MLP  0.069267     0.069040  hidden_layer_sizes=300
# 5  linear MLP  0.070196     0.069056  hidden_layer_sizes=450
# hidden_layer_sizes: 600
#         model  score_cv  score_train                    tags
# 0  linear MLP  0.069149     0.069428   hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342   hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053  hidden_layer_sizes=100
# 3  linear MLP  0.070091     0.070335  hidden_layer_sizes=150
# 4  linear MLP  0.069267     0.069040  hidden_layer_sizes=300
# 5  linear MLP  0.070196     0.069056  hidden_layer_sizes=450
# 6  linear MLP  0.069703     0.069069  hidden_layer_sizes=600
# hidden_layer_sizes: 1000
#         model  score_cv  score_train                     tags
# 0  linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3  linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4  linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5  linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6  linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7  linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# hidden_layer_sizes: 3000
#         model  score_cv  score_train                     tags
# 0  linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3  linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4  linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5  linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6  linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7  linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8  linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# hidden_layer_sizes: 5000
#         model  score_cv  score_train                     tags
# 0  linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1  linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2  linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3  linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4  linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5  linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6  linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7  linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8  linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9  linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# hidden_layer_sizes: 7000
#          model  score_cv  score_train                     tags
# 0   linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1   linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2   linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3   linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4   linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5   linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6   linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7   linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8   linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9   linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10  linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# hidden_layer_sizes: 9000
#          model  score_cv  score_train                     tags
# 0   linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1   linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2   linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3   linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4   linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5   linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6   linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7   linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8   linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9   linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10  linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11  linear MLP  0.069279     0.070523  hidden_layer_sizes=9000

# %%
for hidden_layer_sizes in [10,50,100,150,300,450,600,1000,3000,5000,7000,9000]:
    model = MLPRegressor(hidden_layer_sizes=hidden_layer_sizes)
    print("hidden_layer_sizes:", hidden_layer_sizes)
    scores_dict = scores(model, poly_train, train["logerror"], k, scorer=scorer)
    mlp_results.append({"model": "polynomial MLP", "score_train": scores_dict["train"], "score_cv": scores_dict["validation"], "tags": "hidden_layer_sizes=" + str(hidden_layer_sizes)})
    print(pd.DataFrame(mlp_results))
# Out:
# hidden_layer_sizes: 10
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# hidden_layer_sizes: 50
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# hidden_layer_sizes: 100
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# hidden_layer_sizes: 150
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# hidden_layer_sizes: 300
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# hidden_layer_sizes: 450
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# hidden_layer_sizes: 600
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# 18  polynomial MLP  0.071275     0.069534   hidden_layer_sizes=600
# hidden_layer_sizes: 1000
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# 18  polynomial MLP  0.071275     0.069534   hidden_layer_sizes=600
# 19  polynomial MLP  0.070532     0.072138  hidden_layer_sizes=1000
# hidden_layer_sizes: 3000
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# 18  polynomial MLP  0.071275     0.069534   hidden_layer_sizes=600
# 19  polynomial MLP  0.070532     0.072138  hidden_layer_sizes=1000
# 20  polynomial MLP  0.069157     0.069072  hidden_layer_sizes=3000
# hidden_layer_sizes: 5000
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# 18  polynomial MLP  0.071275     0.069534   hidden_layer_sizes=600
# 19  polynomial MLP  0.070532     0.072138  hidden_layer_sizes=1000
# 20  polynomial MLP  0.069157     0.069072  hidden_layer_sizes=3000
# 21  polynomial MLP  0.070057     0.072051  hidden_layer_sizes=5000
# hidden_layer_sizes: 7000
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# 18  polynomial MLP  0.071275     0.069534   hidden_layer_sizes=600
# 19  polynomial MLP  0.070532     0.072138  hidden_layer_sizes=1000
# 20  polynomial MLP  0.069157     0.069072  hidden_layer_sizes=3000
# 21  polynomial MLP  0.070057     0.072051  hidden_layer_sizes=5000
# 22  polynomial MLP  0.070113     0.069785  hidden_layer_sizes=7000
# hidden_layer_sizes: 9000
#              model  score_cv  score_train                     tags
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# 18  polynomial MLP  0.071275     0.069534   hidden_layer_sizes=600
# 19  polynomial MLP  0.070532     0.072138  hidden_layer_sizes=1000
# 20  polynomial MLP  0.069157     0.069072  hidden_layer_sizes=3000
# 21  polynomial MLP  0.070057     0.072051  hidden_layer_sizes=5000
# 22  polynomial MLP  0.070113     0.069785  hidden_layer_sizes=7000
# 23  polynomial MLP  0.069221     0.073004  hidden_layer_sizes=9000

# %%
# mlp_results_df = pd.DataFrame(mlp_results).sort_values("score_cv")

# %%
mlp_results_df["hidden_layer_sizes"] = mlp_results_df["tags"].apply(lambda value: int(value.split("=")[1]))
mlp_results_df = mlp_results_df.sort_values("hidden_layer_sizes")
# mlp_results_df.to_csv("mlp_results_df.csv", index=False)
mlp_results_df
# Out:
#              model  score_cv  score_train                     tags  \
# 0       linear MLP  0.069149     0.069428    hidden_layer_sizes=10
# 12  polynomial MLP  0.070166     0.071925    hidden_layer_sizes=10
# 1       linear MLP  0.069432     0.069342    hidden_layer_sizes=50
# 13  polynomial MLP  0.069862     0.069176    hidden_layer_sizes=50
# 14  polynomial MLP  0.069386     0.072895   hidden_layer_sizes=100
# 2       linear MLP  0.069399     0.069053   hidden_layer_sizes=100
# 3       linear MLP  0.070091     0.070335   hidden_layer_sizes=150
# 15  polynomial MLP  0.069532     0.069174   hidden_layer_sizes=150
# 4       linear MLP  0.069267     0.069040   hidden_layer_sizes=300
# 16  polynomial MLP  0.069929     0.069090   hidden_layer_sizes=300
# 17  polynomial MLP  0.069176     0.070390   hidden_layer_sizes=450
# 5       linear MLP  0.070196     0.069056   hidden_layer_sizes=450
# 18  polynomial MLP  0.071275     0.069534   hidden_layer_sizes=600
# 6       linear MLP  0.069703     0.069069   hidden_layer_sizes=600
# 19  polynomial MLP  0.070532     0.072138  hidden_layer_sizes=1000
# 7       linear MLP  0.072752     0.069774  hidden_layer_sizes=1000
# 20  polynomial MLP  0.069157     0.069072  hidden_layer_sizes=3000
# 8       linear MLP  0.069816     0.069478  hidden_layer_sizes=3000
# 21  polynomial MLP  0.070057     0.072051  hidden_layer_sizes=5000
# 9       linear MLP  0.069677     0.070703  hidden_layer_sizes=5000
# 10      linear MLP  0.069322     0.068949  hidden_layer_sizes=7000
# 22  polynomial MLP  0.070113     0.069785  hidden_layer_sizes=7000
# 11      linear MLP  0.069279     0.070523  hidden_layer_sizes=9000
# 23  polynomial MLP  0.069221     0.073004  hidden_layer_sizes=9000
#
#     hidden_layer_sizes
# 0                   10
# 12                  10
# 1                   50
# 13                  50
# 14                 100
# 2                  100
# 3                  150
# 15                 150
# 4                  300
# 16                 300
# 17                 450
# 5                  450
# 18                 600
# 6                  600
# 19                1000
# 7                 1000
# 20                3000
# 8                 3000
# 21                5000
# 9                 5000
# 10                7000
# 22                7000
# 11                9000
# 23                9000

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
from bokeh.layouts import gridplot, row
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d3ff0a84-1793-4c25-9038-eb49825e4972">Loading BokehJS ...</span>
#     </div>

# %%
poli_mlp = mlp_results_df[mlp_results_df["model"] == "polynomial MLP"]
linear_mlp = mlp_results_df[mlp_results_df["model"] == "linear MLP"]

# %%
p = figure(width=600, height=400, tools=["save", "xpan", "xwheel_zoom", "reset"], x_axis_label = "n_layers", y_axis_label = "score cv")

# %%
p = figure(width=600, height=400, tools=["save", "xpan", "xwheel_zoom", "reset"], x_axis_label = "n_layers", y_axis_label = "cv_score")

p.line(x=poli_mlp["hidden_layer_sizes"], y=poli_mlp["score_cv"], 
       line_width=2, color="green", legend="polynomial")

p.line(x=linear_mlp["hidden_layer_sizes"], y=linear_mlp["score_cv"], 
       line_width=2, color="red", legend="linear")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ba88a14-b675-4307-b9ed-a6596db21648"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7ba88a14-b675-4307-b9ed-a6596db21648");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ba88a14-b675-4307-b9ed-a6596db21648");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ba88a14-b675-4307-b9ed-a6596db21648' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"356f60d0-09b7-4681-a8ea-4f197de2a378":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"b16b8ceb-ecd0-48a0-8f99-f7af8ccfbd8e","subtype":"Figure","type":"Plot"},"ticker":{"id":"7077770e-3697-4c1e-94d9-a089bc8d4ea0","type":"BasicTicker"}},"id":"8d44d075-b9a2-45a3-8e7d-a981ebcd2f7a","type":"Grid"},{"attributes":{"dimensions":"width","plot":{"id":"b16b8ceb-ecd0-48a0-8f99-f7af8ccfbd8e","subtype":"Figure","type":"Plot"}},"id":"3ed52793-a110-4331-818b-92337a5e5639","type":"WheelZoomTool"},{"attributes":{},"id":"6ed5d403-d1d2-447f-bd26-e53995c4fe18","type":"ToolEvents"},{"attributes":{},"id":"1b8de684-1bb5-40ca-8671-04582a8c2056","type":"LinearScale"},{"attributes":{"items":[{"id":"3971ef67-b064-4337-bc7a-c76874940b0a","type":"LegendItem"},{"id":"31398fb9-dffc-4785-9a09-7a61ac55759a","type":"LegendItem"}],"plot":{"id":"b16b8ceb-ecd0-48a0-8f99-f7af8ccfbd8e","subtype":"Figure","type":"Plot"}},"id":"9b62154a-1f24-4c5f-a0c2-34a5c16d7f8f","type":"Legend"},{"attributes":{},"id":"4cef44d1-6e92-4a5a-8638-aa78c47677f0","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[10,50,100,150,300,450,600,1000,3000,5000,7000,9000],"y":{"__ndarray__":"0KsbmryzsT+uS1VQQ8axPyDJYX4ixLE/85SYCX3xsT+y6bv8dLuxP7nKfjlZ+LE/nHe2YRbYsT/s6okw35+yP3c7Xo5w37E/yKyg9VXWsT8JkV1iGL+xP6oDXtBAvLE/","dtype":"float64","shape":[12]}}},"id":"efc5ff26-0657-4d3d-80a7-f4f74f033275","type":"ColumnDataSource"},{"attributes":{"label":{"value":"polynomial"},"renderers":[{"id":"37c33cf1-a174-40fe-9870-109552eac588","type":"GlyphRenderer"}]},"id":"3971ef67-b064-4337-bc7a-c76874940b0a","type":"LegendItem"},{"attributes":{"label":{"value":"linear"},"renderers":[{"id":"80b2d400-9a04-4c26-ab87-32f1f4bc6a8c","type":"GlyphRenderer"}]},"id":"31398fb9-dffc-4785-9a09-7a61ac55759a","type":"LegendItem"},{"attributes":{"below":[{"id":"e9ec3f4e-6dde-4dfb-a1e4-6f4cd6cf063d","type":"LinearAxis"}],"left":[{"id":"25c7333a-059d-4f83-b7e1-a35c80a9271f","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"e9ec3f4e-6dde-4dfb-a1e4-6f4cd6cf063d","type":"LinearAxis"},{"id":"9bad53e2-ecb3-4575-9a10-8a8794f99bc8","type":"Grid"},{"id":"25c7333a-059d-4f83-b7e1-a35c80a9271f","type":"LinearAxis"},{"id":"8d44d075-b9a2-45a3-8e7d-a981ebcd2f7a","type":"Grid"},{"id":"9b62154a-1f24-4c5f-a0c2-34a5c16d7f8f","type":"Legend"},{"id":"37c33cf1-a174-40fe-9870-109552eac588","type":"GlyphRenderer"},{"id":"80b2d400-9a04-4c26-ab87-32f1f4bc6a8c","type":"GlyphRenderer"}],"title":{"id":"c93b5e01-5aba-48e8-b8b9-f0cf7177e11d","type":"Title"},"tool_events":{"id":"6ed5d403-d1d2-447f-bd26-e53995c4fe18","type":"ToolEvents"},"toolbar":{"id":"8f97b921-5764-4fc3-bb6b-3d7ff184f815","type":"Toolbar"},"x_range":{"id":"01904a21-58fc-4b7e-8a03-e77ee1a37682","type":"DataRange1d"},"x_scale":{"id":"69e3167e-9679-4d71-8278-fca406c61c36","type":"LinearScale"},"y_range":{"id":"3e1e4fd4-a838-490c-8b1a-540e78b44bb1","type":"DataRange1d"},"y_scale":{"id":"1b8de684-1bb5-40ca-8671-04582a8c2056","type":"LinearScale"}},"id":"b16b8ceb-ecd0-48a0-8f99-f7af8ccfbd8e","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"b16b8ceb-ecd0-48a0-8f99-f7af8ccfbd8e","subtype":"Figure","type":"Plot"}},"id":"5974e7aa-8edf-49d5-9ddc-a94dc44f2fd6","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c812b497-9552-40ec-b3d9-46b6aca445ab","type":"SaveTool"},{"id":"71ad3afb-9f71-4e1b-9ad8-1cc3b8e114b3","type":"PanTool"},{"id":"3ed52793-a110-4331-818b-92337a5e5639","type":"WheelZoomTool"},{"id":"5974e7aa-8edf-49d5-9ddc-a94dc44f2fd6","type":"ResetTool"}]},"id":"8f97b921-5764-4fc3-bb6b-3d7ff184f815","type":"Toolbar"},{"attributes":{"dimensions":"width","plot":{"id":"b16b8ceb-ecd0-48a0-8f99-f7af8ccfbd8e","subtype":"Figure","type":"Plot"}},"id":"71ad3afb-9f71-4e1b-9ad8-1cc3b8e114b3","type":"PanTool"},{"attributes":{"plot":{"id":"b16b8ceb-ecd0-48a0-8f99-f7af8ccfbd8e","subtype":"Figure","type":"Plo ...

# %%
geoloc_train.head()
# Out:
#    parcelid  logerror    latitude    longitude
# 0  12149460    0.0363  34225911.0 -118238480.0
# 1  11962551    0.0218  34109753.0 -118227743.0
# 2  10734901    0.0100  34172194.0 -118644314.0
# 3  11104067    0.0060  34429140.0 -118466425.0
# 4  12678699   -0.0111  33835813.0 -118358044.0

# %% [markdown]
# # Modeling v2 - The New Features

# %%
from sklearn.neighbors import NearestNeighbors

# %%
geoloc_train = pd.read_csv("../data/train.csv")[["parcelid", "logerror" ,"latitude", "longitude"]]
geoloc_train = geoloc_train[geoloc_train["latitude"].notnull()]
geoloc_train.head()
# Out:
#    parcelid  logerror    latitude    longitude
# 0  12149460    0.0363  34225911.0 -118238480.0
# 1  11962551    0.0218  34109753.0 -118227743.0
# 2  10734901    0.0100  34172194.0 -118644314.0
# 3  11104067    0.0060  34429140.0 -118466425.0
# 4  12678699   -0.0111  33835813.0 -118358044.0

# %%
geoloc_test = pd.read_csv("../data/test.csv")[["parcelid", "logerror" ,"latitude", "longitude"]]

for column_name in ["latitude", "longitude"]:
    mode = column_mode(geoloc_test[column_name])
    geoloc_test[column_name] = geoloc_test[column_name].fillna(mode)
geoloc_test.head()
# Out:
# (27244, 4)

# %%
nbrs = NearestNeighbors(n_neighbors=4).fit(geoloc_train[["latitude", "longitude"]])

distances_train, indices_train = nbrs.kneighbors(geoloc_train[["latitude", "longitude"]])
distances_test, indices_test = nbrs.kneighbors(geoloc_test[["latitude", "longitude"]])

# %% [markdown]
# ### New feature: 3nn_logerror_median

# %% [markdown]
# The new feature <b>3nn_logerror_median</b> represents the logerror median of the three known closests neighbors.

# %%
geoloc_nn_train = pd.DataFrame(indices_train)
geoloc_nn_test = pd.DataFrame(indices_test)
print(geoloc_nn_train.head())
print(geoloc_nn_test.head())
# Out:
#    0      1      2      3
# 0  0  49784  48917  33909
# 1  1   5722  45897  48565
# 2  2  59270  46722  59939
# 3  3  42881  21948   4544
# 4  4  59642   5195  40087
#        0      1      2      3
# 0  33827    930   4178  47902
# 1  49528  24109  19081  34443
# 2   6283  50993  58290  34681
# 3  21109  23291   2776  50785
# 4  62319  31040  53464  34332

# %%
def map_index_logerror(index, data):
    return data.iloc[index]["logerror"]

def map_index_parcelid(index, data):
    return int(data.iloc[index]["parcelid"])

# %%
nn_logerror_train = pd.DataFrame()
for column in geoloc_nn_train.columns.tolist()[1:]:
    print(column)
    nn_logerror_train[str(column)] = geoloc_nn_train[column].apply(lambda value: map_index_logerror(value, geoloc_train))

nn_logerror_train.head()
# Out:
# 1
# 2
# 3
#         1       2       3
# 0  0.0354 -0.0661 -0.1301
# 1  0.1115  0.0677  0.0469
# 2 -0.0398  0.0545 -0.1143
# 3  0.0296  0.0060  0.0020
# 4 -0.0315  0.0129  0.1856

# %%
nn_logerror_test = pd.DataFrame()
for column in geoloc_nn_test.columns.tolist()[1:]:
    print(column)
    nn_logerror_test[str(column)] = geoloc_nn_test[column].apply(lambda value: map_index_logerror(value, geoloc_train))

nn_logerror_test.head()
# Out:
# 1
# 2
# 3
#         1       2       3
# 0 -0.0471 -0.1054  0.0020
# 1 -0.0050  0.2601  0.0227
# 2  0.0478  0.0010 -0.0131
# 3  0.2343  0.9884  0.0469
# 4 -0.0070  0.0149  0.0564

# %%
nn_logerror_median_train = nn_logerror_train.apply(lambda row: median([row["1"], row["2"], row["3"]]), axis=1)
geoloc_train["3nn_logerror_median"] = nn_logerror_median_train.tolist()
print(len(geoloc_train))
geoloc_train.head()
# Out:
# 63196
#    parcelid  logerror    latitude    longitude  3nn_logerror_median
# 0  12149460    0.0363  34225911.0 -118238480.0              -0.0661
# 1  11962551    0.0218  34109753.0 -118227743.0               0.0677
# 2  10734901    0.0100  34172194.0 -118644314.0              -0.0398
# 3  11104067    0.0060  34429140.0 -118466425.0               0.0060
# 4  12678699   -0.0111  33835813.0 -118358044.0               0.0129

# %%
nn_logerror_median_test = nn_logerror_test.apply(lambda row: median([row["1"], row["2"], row["3"]]), axis=1)
geoloc_test["3nn_logerror_median"] = nn_logerror_median_test.tolist()
print(len(geoloc_test))
geoloc_test.head()
# Out:
# 27244
#    parcelid  logerror    latitude    longitude  3nn_logerror_median
# 0  14366692   -0.1684  33668120.0 -117677556.0              -0.0471
# 1  12643413    0.0218  33755800.0 -118309000.0               0.0227
# 2  14432541   -0.0050  33485643.0 -117700234.0               0.0010
# 3  11509835   -0.2705  33870089.0 -118402768.0               0.2343
# 4  11672170   -0.0161  34072220.0 -118547322.0               0.0149

# %%
geoloc_train["3nn_logerror_median"].corr(geoloc_train["logerror"])
# Out:
# 0.054552937942001105

# %%
train["3nn_logerror_median"] = geoloc_train["3nn_logerror_median"]
train.head()
# Out:
#        parcelid  logerror transactiondate  airconditioningtypeid  \
# 9876   13025861    0.0296      2016-02-17                    1.0
# 52158  11647851    0.1151      2016-07-01                    1.0
# 46312  11198752   -0.0111      2016-06-15                    1.0
# 79157  13915698   -0.0429      2016-09-23                    1.0
# 24214  11882403   -0.0834      2016-04-11                    1.0
#
#        architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 9876                        7.0      0.981443         0.15      0.1875
# 52158                       7.0      0.981443         0.15      0.1875
# 46312                       7.0      0.981443         0.10      0.1875
# 79157                       7.0      0.981443         0.10      0.1875
# 24214                       7.0      0.981443         0.10      0.1875
#
#        buildingclasstypeid  buildingqualitytypeid         ...           \
# 9876                   4.0                    4.0         ...
# 52158                  4.0                    4.0         ...
# 46312                  4.0                    7.0         ...
# 79157                  4.0                    7.0         ...
# 24214                  4.0                    7.0         ...
#
#        fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 9876            True                    0.038490           694000.0
# 52158           True                    0.023772          1131772.0
# 46312           True                    0.014623           185572.0
# 79157           True                    0.002669            49715.0
# 24214           True                    0.020450           589759.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 9876           2015.0               0.012693   0.046075                   Y
# 52158          2015.0               0.036538   0.043089                   Y
# 46312          2015.0               0.001632   0.010412                   Y
# 79157          2015.0               0.000940   0.002622                   Y
# 24214          2015.0               0.015763   0.022623                   Y
#
#        taxdelinquencyyear  censustractandblock  3nn_logerror_median
# 9876                 14.0         6.037401e+13               0.0602
# 52158                14.0         6.037265e+13              -0.0274
# 46312                14.0         6.037911e+13               0.0411
# 79157                14.0         6.059011e+13                  NaN
# 24214                14.0         6.037481e+13               0.0440
#
# [5 rows x 61 columns]

# %%
skb = SelectKBest(k=10)
fit = skb.fit(train[numeric_columns], train["logerror"])

use_columns = train[numeric_columns].columns[fit.get_support()].tolist()
use_columns
