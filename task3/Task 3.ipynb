# %% [markdown]
# # Task 3

# %%
import pandas as pd
import numpy as np

from math import sqrt
from scipy.stats import skew

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100)

# %%
from bokeh.charts import Scatter, Histogram, output_notebook, show
from bokeh.sampledata.autompg import autompg as df
from bokeh.layouts import gridplot
from bokeh.plotting import figure

output_notebook()
# Out:
# /home/tales/anaconda3/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ad46b75d-8f35-4fe3-afc2-669a05f5e9a0">Loading BokehJS ...</span>
#     </div>

# %%
features = ["Vetorial","LPT","P1","IC","LP1","Cálculo2","Discreta","P2","Grafos","Fís.Clássica","LP2","Cálculo1"]
target = "cra"

# %%
def partition(df, train_proportion):
    n_train = round(train_proportion * len(df))
    n_valid = len(df) - n_train
    
    train = df.sample(n_train)
    test_indexes = set(df.index.tolist()) - set(train.index.tolist())
    valid = df.loc[test_indexes]
    return train, valid

def score_rmsd(real, pred):
    assert len(real) == len(pred)
    total = 0
    for i in range(len(real)):
        total += (real[i] - pred[i]) **2
        
    return sqrt(total / len(real))

def scatter_target(df, feature_name):
    p = Scatter(df, x=feature_name, y=target, title="Scatter Plot: " + feature_name, xlabel=feature_name, ylabel=target,
               width=300, height=300, tools=["reset", "pan", "wheel_zoom"], color="blue")

    return p

# %% [markdown]
# ### <font color="blue">Loading data</font>

# %%
data = pd.read_csv("data/treino.csv")[features + [target]]
data.to_csv("data/treino_clean.csv", index=False)
use_data = data.copy()
print(data.shape)
data.head()
# Out:
# (88, 13)
#    Vetorial   LPT   P1   IC  LP1  Cálculo2  Discreta   P2  Grafos  Fís.Clássica  LP2  Cálculo1  \
# 0       8.6  10.0  9.0  9.1  8.6       8.4       8.3  8.8     8.2           7.9  9.4       8.7
# 1       5.6   7.0  7.7  7.0  8.1       6.2       7.3  8.2     5.4           7.7  8.9       7.0
# 2      10.0   9.8  7.9  9.6  8.3       8.7       8.8  9.5     9.2           8.6  9.7       8.6
# 3       6.1   8.3  6.8  8.2  7.1       8.0       6.3  8.9     7.0           8.5  9.0       7.8
# 4       8.8   9.3  5.0  8.5  5.1       5.0       5.8  7.1     5.4           8.7  8.2       5.2
#
#         cra
# 0  8.477647
# 1  6.851724
# 2  9.090588
# 3  7.283516
# 4  7.205747

# %% [markdown]
# ### <font color="blue">Understanding the data</font>

# %% [markdown]
# **Visão geral**

# %%
data.describe()
# Out:
#         Vetorial        LPT         P1         IC        LP1   Cálculo2   Discreta         P2  \
# count  88.000000  88.000000  88.000000  88.000000  88.000000  88.000000  88.000000  88.000000
# mean    7.280682   8.480114   7.407955   8.172727   7.597727   6.323864   6.764773   7.941364
# std     1.404169   0.984522   1.346278   0.894007   1.371799   1.293662   1.228403   0.990478
# min     5.000000   6.200000   5.000000   5.900000   5.000000   5.000000   5.000000   5.300000
# 25%     6.275000   7.700000   6.500000   7.500000   6.600000   5.100000   5.675000   7.300000
# 50%     7.100000   8.500000   7.750000   8.200000   7.800000   5.800000   6.750000   7.950000
# 75%     8.325000   9.300000   8.325000   8.800000   8.600000   7.500000   7.600000   8.800000
# max    10.000000  10.000000  10.000000  10.000000  10.000000   9.300000   9.600000   9.600000
#
#           Grafos  Fís.Clássica        LP2   Cálculo1        cra
# count  88.000000     88.000000  88.000000  88.000000  88.000000
# mean    7.196591      7.107955   8.631818   7.200000   7.332535
# std     1.277970      0.908987   0.969008   1.228493   0.849758
# min     5.000000      5.000000   5.000000   5.000000   4.874468
# 25%     6.300000      7.000000   8.200000   6.275000   6.841484
# 50%     7.200000      7.000000   8.900000   7.200000   7.274746
# 75%     8.200000      7.500000   9.200000   8.125000   7.883292
# max    10.000000      9.100000   9.700000   9.800000   9.090588

# %% [markdown]
# **Distribuições**

# %%
plots = []
for feature in features:
    p = Histogram(data, feature, title="Distribution: " + feature, height=300, width=300)
    plots.append(p)
    
    log_applied = data[feature].apply(np.log)
    exp_applied = data[feature].apply(np.exp)
    
    print("Skewness on " + feature)
    print("Original:", round(skew(data[feature]), 3), ",  Log:", round(skew(log_applied), 3), ",  Exp:", round(skew(exp_applied), 3))
    print()
    
grid = gridplot([plots])
show(gridplot([[plots[0], plots[1], plots[2]]]))
show(gridplot([[plots[3], plots[4], plots[5]]]))
show(gridplot([[plots[6], plots[7], plots[8]]]))
# Out:
# Skewness on Vetorial
# Original: 0.1 ,  Log: -0.217 ,  Exp: 2.354
#
# Skewness on LPT
# Original: -0.311 ,  Log: -0.508 ,  Exp: 0.923
#
# Skewness on P1
# Original: -0.371 ,  Log: -0.651 ,  Exp: 2.329
#
# Skewness on IC
# Original: -0.077 ,  Log: -0.383 ,  Exp: 1.699
#
# Skewness on LP1
# Original: -0.327 ,  Log: -0.578 ,  Exp: 1.721
#
# Skewness on Cálculo2
# Original: 0.53 ,  Log: 0.374 ,  Exp: 2.543
#
# Skewness on Discreta
# Original: 0.347 ,  Log: 0.088 ,  Exp: 2.639
#
# Skewness on P2
# Original: -0.445 ,  Log: -0.741 ,  Exp: 0.983
#
# Skewness on Grafos
# Original: 0.067 ,  Log: -0.276 ,  Exp: 2.607
#
# Skewness on Fís.Clássica
# Original: -0.564 ,  Log: -1.015 ,  Exp: 2.089
#
# Skewness on LP2
# Original: -1.905 ,  Log: -2.413 ,  Exp: 0.172
#
# Skewness on Cálculo1
# Original: 0.028 ,  Log: -0.316 ,  Exp: 2.444
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d8dd2117-068e-4290-a1d6-d32d9537efb9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d8dd2117-068e-4290-a1d6-d32d9537efb9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d8dd2117-068e-4290-a1d6-d32d9537efb9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd8dd2117-068e-4290-a1d6-d32d9537efb9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4a1c311f-2009-4051-8fff-a6762c714ae2":{"roots":{"references":[{"attributes":{"below":[{"id":"43eecf60-39e6-4378-9d23-00c9bcc72a48","type":"LinearAxis"}],"css_classes":null,"height":300,"left":[{"id":"8937584b-2c8e-46f6-b753-f677b7d5866b","type":"LinearAxis"}],"renderers":[{"id":"736a27a0-7806-425a-81f9-fa32a8f8b3c1","type":"BoxAnnotation"},{"id":"ff5274f1-810b-4625-b997-4e576fa899a9","type":"GlyphRenderer"},{"id":"cf8524d5-755b-41b1-9f90-3b14c54566f5","type":"GlyphRenderer"},{"id":"fabc3760-009f-4589-a947-3d269c6880ec","type":"GlyphRenderer"},{"id":"d521962d-ecd4-4443-8f71-9a775ca63248","type":"GlyphRenderer"},{"id":"a63e0342-fc74-4925-9962-ee4f6553041a","type":"GlyphRenderer"},{"id":"8864d237-cb61-4591-93a3-9ca095cd8f23","type":"GlyphRenderer"},{"id":"abcefeff-6c27-47a4-a0ee-8474a8f4b269","type":"Legend"},{"id":"43eecf60-39e6-4378-9d23-00c9bcc72a48","type":"LinearAxis"},{"id":"8937584b-2c8e-46f6-b753-f677b7d5866b","type":"LinearAxis"},{"id":"cb7df81d-c20f-41e6-b916-bf4b9a94ee39","type":"Grid"}],"title":{"id":"bdccb552-118b-4643-9f9a-71e6c6b34336","type":"Title"},"tool_events":{"id":"3ac3eb87-a27e-4b91-8a5e-dba8182669c0","type":"ToolEvents"},"toolbar":{"id":"e8f41389-1280-469d-b730-956389f29e96","type":"Toolbar"},"toolbar_location":null,"width":300,"x_range":{"id":"508522b9-649c-45d2-8041-6c061e04cb41","type":"Range1d"},"x_scale":{"id":"d7832708-3483-4e8b-938f-93a6aabc622d","type":"LinearScale"},"y_range":{"id":"b55d2ec0-b70d-444b-8063-a9dc6938e40d","type":"Range1d"},"y_scale":{"id":"edf3d9df-591a-4a52-bc20-69f1da588bf3","type":"LinearScale"}},"id":"e5feaf9a-5018-4ce4-a699-c027e6485878","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"65c75ce4-614a-41d0-803e-efe73683c8d4","type":"ColumnDataSource"},"glyph":{"id":"237e13dc-f610-4155-8660-90ded4bcd95f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"7e497a3a-db97-4031-a98b-7a56ecf462d2","type":"GlyphRenderer"},{"attributes":{},"id":"af1a0b6f-edb4-459c-b30d-7178bde59fd3","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"237e13dc-f610-4155-8660-90ded4bcd95f","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","y","line_alpha","color","x","label","fill_alpha","line_color","height"],"data":{"chart_index":["(6.666667, 7.500000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[20.0],"label":["(6.666667, 7.500000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.833333333333333],"x":["7.0833335"],"y":[10.0]}},"id":"80b28966-2464-4ac3-863f-6dc409263844","type":"ColumnDataSource"},{"attributes":{},"id":"598add91-9784-4d3d-b8ef-2c4406084688","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"694a53db-92b3-4d50-924c-eabfe00dee5a","type":"Row"}]},"id":"88e73854-5464-4829-b767-8ce11542b332","type":"Column"},{"attributes":{"dimension":1,"plot":{"id":"e5feaf9a-5018-4ce4-a699-c027e6485878","subtype":"Chart","type":"Plot"},"ticker":{"id":"78c784cf-61f3-4dc8-8b25-5d94108b472c","type":"BasicTicker"}},"id":"cb7df81d-c20f-41e6-b916-bf4b9a94ee39","type":"Grid"},{"attributes":{"plot":{"id":"e5feaf9a-5018-4ce4-a699-c027e6485878","subtype":"Chart","type":"Plot"}},"id":"aac77b0f-4648-4620-937c-e8b4c16b8d15","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"1a4e5181-16fe-4aec-8230-69a1e03c8e3d","subtype":"Chart","type":"Plot"},"ticker":{"id":"6af51336-82e4-467b-98b7-a80cf10ad2ec","type":"BasicTicker"}},"id":"2f5a7324-a249-4f5f-baa3-4b2f957bf971","type":"Grid"},{"attributes":{},"id":"edf3d9df-591a-4a52-bc20-69f1da588bf3","type":"LinearScale"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="44d56fdc-e4de-4481-b834-1fd852747875"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("44d56fdc-e4de-4481-b834-1fd852747875");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("44d56fdc-e4de-4481-b834-1fd852747875");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '44d56fdc-e4de-4481-b834-1fd852747875' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"36f0658f-18e4-4d75-b862-1f923713b976":{"roots":{"references":[{"attributes":{"data_source":{"id":"aed69a28-6ad2-43d3-b284-bccb7ffab05f","type":"ColumnDataSource"},"glyph":{"id":"3fd95955-002a-474d-89a8-1901040f336d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"6bc7688c-7ab5-4114-9cf9-4d6a168125fe","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","y","line_alpha","color","x","label","fill_alpha","line_color","height"],"data":{"chart_index":["(7.500000, 8.333333]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[20.0],"label":["(7.500000, 8.333333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8333333333333339],"x":["7.9166665"],"y":[10.0]}},"id":"b9deb3c9-7937-4bd7-ad93-87756c46c8e6","type":"ColumnDataSource"},{"attributes":{"location":"top_left","plot":{"id":"4e0446c1-9de9-4bea-b04a-177b755ef630","subtype":"Chart","type":"Plot"}},"id":"7fc1d387-da0e-45d7-b565-dd7cef64f759","type":"Legend"},{"attributes":{"callback":null,"end":10.3975,"start":5.5025},"id":"4ccc39d8-034d-4dc6-b162-328e34053550","type":"Range1d"},{"attributes":{"axis_label":"Count( Ic )","formatter":{"id":"6e7a9dd0-82c0-48ef-a445-f3d20a0f2632","type":"BasicTickFormatter"},"plot":{"id":"303acde6-49d3-4bf4-ae31-e59c1e8b0f83","subtype":"Chart","type":"Plot"},"ticker":{"id":"ea5ae01a-b7d8-4dcb-961c-059e28f686be","type":"BasicTicker"}},"id":"ee213cea-9895-46e3-9c93-5adf2493c2be","type":"LinearAxis"},{"attributes":{"axis_label":"Count( Lp1 )","formatter":{"id":"d299549f-32b2-4091-b90d-a4759cb9c312","type":"BasicTickFormatter"},"plot":{"id":"4e0446c1-9de9-4bea-b04a-177b755ef630","subtype":"Chart","type":"Plot"},"ticker":{"id":"8cfd3255-7e92-4d42-9743-747ef14279ec","type":"BasicTicker"}},"id":"26456acd-4ea2-49c2-8cea-1c6f1b1d3913","type":"LinearAxis"},{"attributes":{"plot":{"id":"303acde6-49d3-4bf4-ae31-e59c1e8b0f83","subtype":"Chart","type":"Plot"}},"id":"19ae9c63-4015-4c0e-a622-269204d9d5cd","type":"HelpTool"},{"attributes":{},"id":"e9bdb89b-3902-42b5-8ba2-1c2f734e0235","type":"LinearScale"},{"attributes":{},"id":"19ff70d0-5321-4cc1-bccc-4092924dfe3d","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"ee13e78c-6491-45a9-99d7-116b331118e9","type":"ToolbarBox"},{"id":"57dc973e-68e6-4ff7-a94b-7e810d85948f","type":"Column"}]},"id":"d217d610-ac78-41e6-89fd-bc28d2e82dfa","type":"Column"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"26ca7fa9-1278-4c45-b5cd-08afbd2ae334","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3fd95955-002a-474d-89a8-1901040f336d","type":"Rect"},{"attributes":{"children":[{"id":"303acde6-49d3-4bf4-ae31-e59c1e8b0f83","subtype":"Chart","type":"Plot"},{"id":"4e0446c1-9de9-4bea-b04a-177b755ef630","subtype":"Chart","type":"Plot"},{"id":"d9795a36-afe1-41d3-9713-e2d62d2087c7","subtype":"Chart","type":"Plot"}]},"id":"7fc6d87e-59c0-485a-a12e-600ce77de516","type":"Row"},{"attributes":{"plot":{"id":"d9795a36-afe1-41d3-9713-e2d62d2087c7","subtype":"Chart","type":"Plot"}},"id":"3c7bd066-53b5-43b2-b719-de505a21e43a","type":"HelpTool"},{"attributes":{},"id":"9594bf63-b277-4831-94d1-fa4e2fb9515b","type":"ToolEvents"},{"attributes":{"callback":null,"end":24.200000000000003},"id":"f7c31f23-b449-4f67-9701-82f5ae4f0433","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f0f531a1-b4ff-43e5-86d0-07269718b378","type":"Rect"},{"attributes":{"callback":null,"column_name ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7aa5315a-ef8c-4ba5-8eaa-4271eb189661"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7aa5315a-ef8c-4ba5-8eaa-4271eb189661");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7aa5315a-ef8c-4ba5-8eaa-4271eb189661");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7aa5315a-ef8c-4ba5-8eaa-4271eb189661' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d0d238eb-11f1-4f65-9be3-e5e011880eed":{"roots":{"references":[{"attributes":{"children":[{"id":"27f5154a-7c64-4deb-97d4-5ff2b1f00ac1","type":"Row"}]},"id":"b4d3a35c-aa7e-4c3b-b7b9-e7f00900a104","type":"Column"},{"attributes":{"data_source":{"id":"2704aacd-c352-48d3-aaf0-0fa87a0f7eb5","type":"ColumnDataSource"},"glyph":{"id":"08e3c1fc-1e22-44fe-9632-48677de902ea","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e7b465e3-575b-4ac3-9c47-596b335af04d","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"47e825c4-ff94-47c3-8191-51a2a55a9b95","type":"BoxAnnotation"},"plot":{"id":"3bec0b20-b34b-4fe1-bf07-5bf4a604d670","subtype":"Chart","type":"Plot"}},"id":"485b2b57-5eeb-438d-b576-c7c18496584d","type":"BoxZoomTool"},{"attributes":{},"id":"0e8c7472-9970-40d3-9d7b-082687a759d1","type":"BasicTicker"},{"attributes":{"plot":{"id":"e73a348e-257a-4aa5-9203-8aebee4bb7a7","subtype":"Chart","type":"Plot"}},"id":"c005a9d7-dae6-4125-bfde-b9fc2af2db62","type":"WheelZoomTool"},{"attributes":{},"id":"9fa44b36-160c-4437-876c-7b18f3b77da8","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["width","y","line_alpha","color","x","label","fill_alpha","line_color","height"],"data":{"chart_index":["(7.757143, 8.371429]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[20.0],"label":["(7.757143, 8.371429]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6142857142857139],"x":["8.064286"],"y":[10.0]}},"id":"7f3c814c-47b1-4b46-acd4-6b65bfed3937","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"3d7df06c-8713-40e5-b0c7-ea7d586d692c","subtype":"Chart","type":"Plot"}},"id":"9662d012-c98a-4731-a079-8550fc06aa94","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["width","y","line_alpha","color","x","label","fill_alpha","line_color","height"],"data":{"chart_index":["(5.914286, 6.528571]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[8.0],"label":["(5.914286, 6.528571]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6142857142857148],"x":["6.2214285"],"y":[4.0]}},"id":"2bbc576f-d3d1-42ed-993e-ccb1929044f3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cef3b813-ae71-4d39-a805-81a6145bb397","type":"ColumnDataSource"},"glyph":{"id":"a7db16c7-ce6b-4c93-9536-980237816e5b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4733ad63-fd05-4db4-ab91-ac9d5e1eeccf","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"95bd1a00-ca64-4c7a-a379-aee03fab740e","type":"ColumnDataSource"},"glyph":{"id":"f993333b-0986-49d4-81c8-b4c60ef24a51","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"3d7c41fb-8177-47c3-9fed-eda0893a4b12","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1ad7c253-9475-4b26-b618-91a04f9aa9cf","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","y","line_alpha","color","x","label","fill_alpha","line_color","height"],"data":{"chart_index":["(8.333333, 9.166667]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[10.0],"label":["(8.333333, 9.166667]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8333333333333339],"x":["8.75"],"y":[5.0]}},"id":"4098f242-98af-4ff3-9e0a-b3ef3fe20245","type":"ColumnDataSource"},{"attributes":{"axis_label":"Grafos","formatter":{"id":"1cbda3e3-ad5a-4063-a3f4-64c595afbe2e","type":"BasicTickFormatter"},"plot":{"id":"3d7df06c-8713-40e5-b0c7-ea7d586d692c","subtype":"Chart","type":"Plot"},"ticker":{"id":"a74dfeb2-664e-469b-9c6f-525a2df9f541","type":"BasicTicker"}},"id":"d56b4323-7c1d-4085-b6bb-89bb1852bd97","type":"LinearAxis"},{"attributes":{"callback":null,"end":10.375000166666666,"start":4.624999833333334},"id":"8e4da906-4385-4f1f-a46b-8a59a3f0afd4","type":"Range1d"},{"attributes":{"callback":null,"column_names":["width","y","line_alpha","color","x","label","fi ...

# %% [markdown]
# Mudanças a serem aplicadas nas features baseadas em suas nas distribuições:
# - **Log**: Cálculo2, Discreta
# - **Exp**: LP2

# %%
use_data["Cálculo2"] = data["Cálculo2"].apply(np.log)
use_data["Discreta"] = data["Discreta"].apply(np.log)
use_data["LP2"] = data["LP2"].apply(np.exp)

# %% [markdown]
# **Relações**

# %%
plots = []

for feature in features:
    p = scatter_target(use_data, feature)
    plots.append(p)

grid = gridplot([[plots[0], plots[1], plots[2]],
                 [plots[3], plots[4], plots[5]],
                 [plots[6], plots[7], plots[8]],
                 [plots[9], plots[10], plots[11]]])

show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aff0824e-9805-49ec-8870-754981bad451"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("aff0824e-9805-49ec-8870-754981bad451");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aff0824e-9805-49ec-8870-754981bad451");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aff0824e-9805-49ec-8870-754981bad451' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"00e3805f-7b92-494d-90c6-bef9e06eb3bf":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"8a18bbb1-1fc1-4c42-b76c-ebdf4079b34f","type":"Circle"},{"attributes":{"plot":{"id":"f7733a52-6780-4d18-b6ff-e0747ed71185","subtype":"Chart","type":"Plot"},"ticker":{"id":"bac029fb-a844-433e-9736-e1c139f36946","type":"BasicTicker"}},"id":"111c5493-404a-4aa4-95ab-de3435b93a74","type":"Grid"},{"attributes":{"plot":{"id":"a7ac2585-fc3e-4cdd-a2b8-2c71a43c8ead","subtype":"Chart","type":"Plot"}},"id":"5af7fd1e-e4af-478c-bb2a-a35558ff66e2","type":"PanTool"},{"attributes":{"plot":{"id":"5142b450-5347-4259-8fa3-00447717b503","subtype":"Chart","type":"Plot"}},"id":"be4fc868-650e-456a-8ebf-84e5e8a7c1e2","type":"ResetTool"},{"attributes":{},"id":"900eee83-78f4-43a0-b301-54e1b008992b","type":"BasicTicker"},{"attributes":{"callback":null,"end":9.512200250312892,"start":4.452856070087609},"id":"cd5d2e42-9264-4830-9b3b-8e17d0056881","type":"Range1d"},{"attributes":{},"id":"c03c8a1b-e0ed-490b-a6a4-a332a5af91d9","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":{"__ndarray__":"...","dtype":"float64","shape":[88]},"y_values":{"__ndarray__":"...","dtype":"float64","shape":[88]}}},"id":"5f651116-1090-45e3-a29d-398580faa2d1","type":"ColumnDataSource"},{"attributes":{"axis_label":"LPT","formatter":{"id":"379e5745-7b42-4009-8b5c-9299427b2b99","type":"BasicTickFormatter"},"plot":{"id":"43112d22-9b60-4085-a7fd-2b47516360c9","subtype":"Chart","type":"Plot"},"ticker":{"id":"13fc45bb-9ba2-4b8b-8f77-03d3384d4732","type":"BasicTicker"}},"id":"4f9e4afd-b030-462b-a73d-8783c57667ab","type":"LinearAxis"},{"attributes":{},"id":"bedda34a-b32d-4072-b312-ea19963b4a1d","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dc1c634d-4fca-4d18-9f7b-33da5b476daf","type":"ResetTool"},{"id":"908019d9-5c8c-406f-a2f3-871140ab0536","type":"PanTool"},{"id":"31c42995-555d-4822-a39a-9d5cc3f6fbc0","type":"WheelZoomTool"}]},"id":"f429e26f-636f-48f6-8551-e4a252a7669c","type":"Toolbar"},{"attributes":{"children":[{"id":"130a2354-f160-4dce-9fa7-98695367e443","subtype":"Chart","type":"Plot"},{"id":"72cd101b-b750-4d18-9d18-1ee3ea4be4d5","subtype":"Chart","type":"Plot"},{"id":"a7ac2585-fc3e-4cdd-a2b8-2c71a43c8ead","subtype":"Chart","type":"Plot"}]},"id":"2883ace8-5828-4d80-8d51-007d87202dda","type":"Row"},{"attributes":{"location":"top_left","plot":{"id":"f7733a52-6780-4d18-b6ff-e0747ed71185","subtype":"Chart","type":"Plot"}},"id":"b8f447ed-6847-4d02-ac6a-8c86e9bfb1e9","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"88aae0fd-aa45-49a3-9bde-614ecf3b8fd2","subtype":"Chart","type":"Plot"},"ticker":{"id":"fe91aa00-81e9-4b18-b97a-3d93d007df26","type":"BasicTicker"}},"id":"c61f32be-b953-48b0-9b34-1b3d83302c81","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1db5656f-66a3-4755-ad79-f07f1b6a2b93","type":"ResetTool"},{"id":"2061bf05-d53e-415b-ad2b-042af8896ab9","type":"PanTool"},{"id":"1be8ff33-20d8-4478-af02-bc3bd7877cd6","type":"WheelZoomTool"}]},"id":"5af70a15-8ee3-447b-9b60-20eab7a999f2","type":"Toolbar"},{"attributes":{"data_source":{"id":"9fee8fe6-3d0f-4b87-ad91-e89962290b19","type":"ColumnDataSource"},"glyph":{"id":"e04 ...

# %%
train, valid = partition(data, 0.7)

# %%
print("train:", train.shape)
print("valid:", valid.shape)
# Out:
# train: (62, 13)
# valid: (26, 13)

# %% [markdown]
# ### Models

# %%
from my_regression import MyRegression
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score

# %%
def plot_lines(x, y, title=""):
    p = figure(plot_width=600, plot_height=250, title=title, tools=["reset", "pan", "xwheel_zoom"])
    p.line(x, y, color="navy", line_width=2)
    show(p)

# %%
def rmse_cv(model, x, y):
    rmse= np.sqrt(-cross_val_score(model, x, y, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

# %%
y = use_data[target]
del use_data[target]

# %% [markdown]
# **Ridge**

# %%
alphas = [0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 20, 25, 30, 35, 50, 75, 100]

# %%
model_ridge = Ridge()
cv_ridge = [rmse_cv(Ridge(alpha = alpha, ), use_data.as_matrix(), y.as_matrix()).mean() for alpha in alphas]
    
plot_lines(alphas, cv_ridge)
print("min rmse:", min(cv_ridge))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bd2254b8-b91e-49dc-a9e9-612386cb2d13"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bd2254b8-b91e-49dc-a9e9-612386cb2d13");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd2254b8-b91e-49dc-a9e9-612386cb2d13");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd2254b8-b91e-49dc-a9e9-612386cb2d13' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"70af9c2b-e06b-46bd-9c97-a25a7e21810a":{"roots":{"references":[{"attributes":{},"id":"fcd486ce-318f-4d7d-b794-77a254dcaf2e","type":"ToolEvents"},{"attributes":{"plot":{"id":"eca07d3a-6306-4ec6-950a-a0a1bedea424","subtype":"Figure","type":"Plot"},"ticker":{"id":"fb7bc7fa-9b24-43c1-8f55-05beeb7051a4","type":"BasicTicker"}},"id":"be2b31c4-9bb5-4900-b34f-fc99169448e3","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb98f3de-2d78-4a39-8290-c2e6438011a2","type":"Line"},{"attributes":{"data_source":{"id":"cb5ff090-48a2-44cb-a211-b1e9b590e5ab","type":"ColumnDataSource"},"glyph":{"id":"f8b965da-606f-4670-acdd-c7d7ee100f72","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fb98f3de-2d78-4a39-8290-c2e6438011a2","type":"Line"},"selection_glyph":null},"id":"98e1db65-d342-4f45-9e5a-bb9d85acb5d6","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"eca07d3a-6306-4ec6-950a-a0a1bedea424","subtype":"Figure","type":"Plot"}},"id":"d95667d2-669a-47b7-a226-27122c991112","type":"PanTool"},{"attributes":{},"id":"6040b8a5-50d0-4e4f-bc30-6c1fbcf60d34","type":"LinearScale"},{"attributes":{},"id":"55678a99-1c75-4c3a-b712-d338991e73c5","type":"BasicTicker"},{"attributes":{"plot":{"id":"eca07d3a-6306-4ec6-950a-a0a1bedea424","subtype":"Figure","type":"Plot"}},"id":"bb36d822-3075-4485-b73f-7d4dee21c5d5","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.05,0.1,0.3,1,3,5,10,15,20,25,30,35,50,75,100],"y":[0.5933290460729129,0.5922964449915382,0.5894461650700111,0.5860405589479798,0.5840368407560577,0.5821995637296273,0.5777666631012724,0.5745431542463957,0.5724334271618068,0.5711645805546541,0.5705198413587542,0.5703426368397537,0.5716322711218635,0.5768125496652446,0.5833425195314781]}},"id":"cb5ff090-48a2-44cb-a211-b1e9b590e5ab","type":"ColumnDataSource"},{"attributes":{},"id":"970754f3-8f0a-4116-8f6e-04c11c9d138e","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"eca07d3a-6306-4ec6-950a-a0a1bedea424","subtype":"Figure","type":"Plot"},"ticker":{"id":"55678a99-1c75-4c3a-b712-d338991e73c5","type":"BasicTicker"}},"id":"0eb11887-0f15-41df-9ba2-38de46d5cc3e","type":"Grid"},{"attributes":{},"id":"fb7bc7fa-9b24-43c1-8f55-05beeb7051a4","type":"BasicTicker"},{"attributes":{"formatter":{"id":"970754f3-8f0a-4116-8f6e-04c11c9d138e","type":"BasicTickFormatter"},"plot":{"id":"eca07d3a-6306-4ec6-950a-a0a1bedea424","subtype":"Figure","type":"Plot"},"ticker":{"id":"fb7bc7fa-9b24-43c1-8f55-05beeb7051a4","type":"BasicTicker"}},"id":"87b9e0a9-3ad5-416f-8711-d6629c5a20f8","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bb36d822-3075-4485-b73f-7d4dee21c5d5","type":"ResetTool"},{"id":"d95667d2-669a-47b7-a226-27122c991112","type":"PanTool"},{"id":"7be72863-6a7b-48e8-9d8c-7e63b6acd478","type":"WheelZoomTool"}]},"id":"d9f0c71d-2c23-4afe-9256-87ce7a14d24b","type":"Toolbar"},{"attributes":{"formatter":{"id":"971d0548-0aee-4c5b-bbed-407b307fb5cc","type":"BasicTickFormatter"},"plot":{"id":"eca07d3a-6306-4ec6-950a-a0a1bedea424","subtype":"Figure","type":"Plot"},"ticker":{"id":"55678a99-1c75-4c3a-b712-d338991e73c5","type":"BasicTicker"}},"id":"3b3a2b5b-a955-4f98-988b-8a3ae34d61c6","type":"LinearAxis"},{"attributes":{"callback":null},"id":"e4516371-16f6-45a3-88b3-ee29e87ccb24","type":"DataRange1d"},{"attributes":{"below":[{"id":"87b9e0a9-3ad5-416f-8711-d6629c5a20f8","type":"LinearAxis"}],"left":[{"id":"3b3a2b5b-a955-4f98-988b-8a3ae34d61c6","type":"LinearAxis"}],"plot_height":250,"renderers":[{"id":"87b9e0a9-3ad5-416f-8711-d6629c5a20f8","type":"LinearAxis"},{"id":"be2b31c4-9bb5-4900-b34f-fc99169448e3","type":"Grid"},{"id":"3b3a2b5b-a955-4f98-988b-8a3ae34d61c6","type":"LinearAxis"},{"id":"0eb11887-0f15-41df-9ba2-38de46d5cc3e","type":"Grid"},{"id":"98e1db65-d342-4f45-9e5a-bb9 ...
# min rmse: 0.57034263684

# %% [markdown]
# **Lasso**

# %%
model_lasso = LassoCV(alphas = [1, 0.1, 0.001, 0.0005]).fit(use_data.as_matrix(), y.as_matrix())

# %%
mr = MyRegression("data/treino_clean.csv", header=True)
w_array, rss = mr.run(learning_rate=0.0000001, verbosity="v")
# Out:
# ---
# Final RSS: 0.326764706
#
# w0: 0.010776940833
# w1: 0.0791133046615
# w2: 0.0900471562901
# w3: 0.0778791693115
# w4: 0.0885023295072
# w5: 0.0803464175717
# w6: 0.0654059858306
# w7: 0.0750617752168
# w8: 0.0864577487894
# w9: 0.079041725702
# w10: 0.0764539904215
# w11: 0.0914668376727
# w12: 0.0768106150714
